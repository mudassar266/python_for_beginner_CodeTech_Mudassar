# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# load data set 
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
# plot scatter plot
sns.scatterplot(x='age', y='bought_insurance', data=df)
# Out:
# <Axes: xlabel='age', ylabel='bought_insurance'>

# %%
# split data into features and target
X = df[['age']]
y = df['bought_insurance']

# %%
# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_test
# Out:
#     age
# 22   40
# 15   55
# 3    52

# %%
# create logistic regression model
model = LogisticRegression()

# %%
# model training
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# model prediction
predictions = model.predict(X_test)
predictions
# Out:
# array([1, 1, 1])

# %%
# model predict 
model.predict([[25]])
# Out:
# c:\Users\Mudassar Khalid\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# model evaluation
model.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
import numpy as np

import matplotlib.pyplot as plt

# create a grid of points
x_min, x_max = X['age'].min() - 1, X['age'].max() + 1
xx = np.linspace(x_min, x_max, 100).reshape(-1, 1)

# make predictions on the grid points
yy = model.predict(xx)

# plot the decision boundary
plt.scatter(X['age'], y, color='blue', label='Data points')
plt.plot(xx, yy, color='red', label='Decision boundary')
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.title('Logistic Regression Decision Boundary')
plt.legend()
plt.show()
# Out:
# c:\Users\Mudassar Khalid\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
# now plot teh decision boundary
import matplotlib.pyplot as plt
import numpy as np
# create a grid of points
x_min, x_max = X['age'].min() - 1, X['age'].max() + 1
xx = np.linspace(x_min, x_max, 100).reshape(-1, 1)
# make predictions on the grid points
yy = model.predict(xx)
# plot the decision boundary
plt.scatter(X['age'], y, color='blue', label='Data points')
plt.plot(xx, yy, color='red', label='Decision boundary')
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.title('Logistic Regression Decision Boundary')
plt.legend()
plt.show()
