# %% [markdown]
# # aaj hum naive bayes algorithm kren gy to predict survival in titanic

# %%
# import neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load titanic datset 
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df_new = df.drop(columns=['alive', 'who', 'deck', 'embark_town', 'alone', 'sibsp', 'parch',
                          'embarked', 'class', 'who', 'adult_male', 'deck','alive', 'alone' ], inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age     fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
# now data preprocesisng 

# check for null values
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# fare          0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(), inplace=True)
# Out:
# C:\Users\Mudassar Khalid\AppData\Local\Temp\ipykernel_19792\1503503937.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# fare        0
# dtype: int64

# %%
df['sex'] = df['sex'].map({'male': 1, 'female': 0})
df.head()
# Out:
#    survived  pclass  sex   age     fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
# defining features and target variable
inputs = df.drop(columns=['survived'])
target = df['survived']

# %%
# now splitting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2, random_state=42)
# check the shape of the data
print(X_train.shape)
print(X_test.shape)
# Out:
# (712, 4)
# (179, 4)

# %%
# now traing the naive bayes model
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
model.score(X_train, y_train)
# Out:
# 0.7808988764044944

# %%
X_test.head()
# Out:
#      pclass  sex        age     fare
# 709       3    1  29.699118  15.2458
# 439       2    1  31.000000  10.5000
# 840       3    1  20.000000   7.9250
# 720       2    0   6.000000  33.0000
# 39        3    0  14.000000  11.2417

# %%
y_test.head(5)
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
# Name: survived, dtype: int64

# %%
model.predict(X_test[:5])
# Out:
# array([0, 0, 0, 1, 1])

# %%
model.predict_proba(X_test[:5])
# Out:
# array([[0.96838166, 0.03161834],
#        [0.93408322, 0.06591678],
#        [0.96236118, 0.03763882],
#        [0.14010625, 0.85989375],
#        [0.35305418, 0.64694582]])
